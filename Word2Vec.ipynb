# %%
pip install gensim
# Out:
# Collecting gensim
#   Downloading https://files.pythonhosted.org/packages/0b/66/04faeedb98bfa5f241d0399d0102456886179cabac0355475f23a2978847/gensim-3.8.3-cp37-cp37m-win_amd64.whl (24.2MB)
# Requirement already satisfied: scipy>=0.18.1 in c:\users\g50\anaconda3\lib\site-packages (from gensim) (1.4.1)
# Requirement already satisfied: six>=1.5.0 in c:\users\g50\appdata\roaming\python\python37\site-packages (from gensim) (1.14.0)
# Collecting Cython==0.29.14 (from gensim)
#   Downloading https://files.pythonhosted.org/packages/1f/be/b14be5c3ad1ff73096b518be1538282f053ec34faaca60a8753d975d7e93/Cython-0.29.14-cp37-cp37m-win_amd64.whl (1.7MB)
# Collecting smart-open>=1.8.1 (from gensim)
#   Downloading https://files.pythonhosted.org/packages/74/77/744c79da6e66691e3500b6dffff29bdd787015eae817d594791edc7b719b/smart_open-2.0.0.tar.gz (103kB)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\g50\anaconda3\lib\site-packages (from gensim) (1.16.4)
# Requirement already satisfied: requests in c:\users\g50\anaconda3\lib\site-packages (from smart-open>=1.8.1->gensim) (2.22.0)
# Requirement already satisfied: boto in c:\users\g50\anaconda3\lib\site-packages (from smart-open>=1.8.1->gensim) (2.49.0)
# Collecting boto3 (from smart-open>=1.8.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/6d/e3/bdd48e60b6ec83e77c4f5e300aff9999f0eac97f92b468cc69bd0871f096/boto3-1.13.25.tar.gz (97kB)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\g50\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\g50\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (2019.6.16)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\g50\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\g50\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (2.8)
# Collecting botocore<1.17.0,>=1.16.25 (from boto3->smart-open>=1.8.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/38/ea/7e41f120d364b3e8f854336c900bd80abd74e6d72b2280e195e3195027a4/botocore-1.16.25-py2.py3-none-any.whl (6.2MB)
# Collecting jmespath<1.0.0,>=0.7.1 (from boto3->smart-open>=1.8.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/07/cb/5f001272b6faeb23c1c9e0acc04d48eaaf5c862c17709d20e3469c6e0139/jmespath-0.10.0-py2.py3-none-any.whl
# Collecting s3transfer<0.4.0,>=0.3.0 (from boto3->smart-open>=1.8.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/69/79/e6afb3d8b0b4e96cefbdc690f741d7dd24547ff1f94240c997a26fa908d3/s3transfer-0.3.3-py2.py3-none-any.whl (69kB)
# Requirement already satisfied: docutils<0.16,>=0.10 in c:\users\g50\anaconda3\lib\site-packages (from botocore<1.17.0,>=1.16.25->boto3->smart-open>=1.8.1->gensim) (0.14)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\g50\anaconda3\lib\site-packages (from botocore<1.17.0,>=1.16.25->boto3->smart-open>=1.8.1->gensim) (2.8.0)
# Building wheels for collected packages: smart-open, boto3
#   Building wheel for smart-open (setup.py): started
#   Building wheel for smart-open (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\G50\AppData\Local\pip\Cache\wheels\27\65\38\8d7f5fe8d7afb4e4566587b2d1933cec185fba19257836c943
#   Building wheel for boto3 (setup.py): started
#   Building wheel for boto3 (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\G50\AppData\Local\pip\Cache\wheels\dc\be\26\b8eb33efc648c5a8bc96c8e2fca8a2ff5327fc00289c3ff9ef
# Successfully built smart-open boto3
# Installing collected packages: Cython, jmespath, botocore, s3transfer, boto3, smart-open, gensim
#   Found existing installation: Cython 0.29.12
#     Uninstalling Cython-0.29.12:
#       Successfully uninstalled Cython-0.29.12
# Successfully installed Cython-0.29.14 boto3-1.13.25 botocore-1.16.25 gensim-3.8.3 jmespath-0.10.0 s3transfer-0.3.3 smart-open-2.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import re
import nltk
from gensim.models import Word2Vec
from nltk.corpus import stopwords

# %%
import pandas as pd

# %%
data = pd.read_csv("ramayana.csv")

# %%
data
# Out:
#                                                    Data
# 0     The  Bharatiya  Vidya   Bhavan   has added to ...
# 1     Once again, I repeat my  confession  that in t...
# 2     At any rate, they embody the best joy I have e...
# 3     In presenting this English version to a wider ...
# 4     The Ramayana is not history  or biography.  It...
# 5     towards  things  spiritual  which  belongs  to...
# 6     The Bharatiya Vidya Bhavan  has achieved great...
# 7     Oral discourses have further played with them ...
# 8     We should be thankful to those who preserved f...
# 9     Mythology is  an  integral  part  of  religion...
# 10    Let us keep ever in our minds the fact  that i...
# 11    To the north of the Ganga was the great kingdo...
# 12    King Dasaratha  ruled   the   kingdom from the...
# 13    fought on the side of the Devas,  and  his fam...
# 14    It contained forts with moats around them as  ...
# 15    Taxes were light and  punishment  of  crime wa...
# 16    One day in early summer he thought of performi...
# 17    It meant the building of a  new  camp- city, c...
# 18    When all arrangements were  complete  the cere...
# 19                         as enjoined by the Shastras.
# 20    Contemporaneously with the yaga in Ayodhya, th...
# 21    refuge and it is for you to devise  a method  ...
# 22    Brahma knew that he had granted to Ravana the ...
# 23    Absolutely surrendering themselves to Hari, th...
# 24    Calling  King  Dasaratha  by  his  name, the f...
# 25    He asked Kausalya to drink  a  half  of the pa...
# 26                                   2. SAGE VISWAMITRA
# 27    In course of time, Dasaratha's sons were born ...
# 28    of Kaikeyi. Sumitra gave birth to twins, Laksh...
# 29    In proportion to the  quantity of payasam drun...
# ...                                                 ...
# 2597  In love that is not opposed  to  dharma, we fi...
# 2598  Those who regard the Ramayana as an allegory  ...
# 2599  There are also other interpretations and appli...
# 2600  Parvati's  function  in  relation   to   Siva ...
# 2601  Many meanings can be  read in  the Ramayana an...
# 2602  many faults in  what  I  have  written.  But t...
# 2603  A word to the children who read these chapters...
# 2604  You should look  upon  Rama, Lakshmana and Han...
# 2605  Mothers too, I know, have been reading this st...
# 2606  The story of Sita  as  told by  Valmiki  and K...
# 2607  In the Rama avatar,  Rama  did  not  know that...
# 2608  knew that he was an avatar and acted according...
# 2609  led the warrior to destroy the wicked. In ever...
# 2610  I have followed the story  of  the  Prince of ...
# 2611  This pathetic episode must have sprung from th...
# 2612  As the prince returned from Mithila he  met Pa...
# 2613  On this  theory, Rama's treatment  of Sita aft...
# 2614  But, how can we comment on a work composed tho...
# 2615  Sorrow and joy are both  alike  the play of Go...
# 2616  men and women, and enacted with her a great dr...
# 2617  Rain falling from the heaven  flows  into the ...
# 2618  Thus in every land the poets and their people ...
# 2619  Does a plant spring from the seed  or  does se...
# 2620  One other point, in describing how Ravana carr...
# 2621  It is no sin or shame to an innocent woman   i...
# 2622  Yet, mistakenly,  we  in  this country  look o...
# 2623  deference to this  wrong  feeling  that Kamban...
# 2624  For the same reason, Tulasidas relates that th...
# 2625  It was perhaps presumptuous on  my part to hav...
# 2626  When I had to step down from  high  office and...
#
# [2627 rows x 1 columns]

# %%
data.isna().sum()
# Out:
# Data    0
# dtype: int64

# %%
data = data.dropna(axis = 0)

# %%
data.isna().sum()
# Out:
# Data    0
# dtype: int64

# %%
data.shape
# Out:
# (2627, 1)

# %%
data.describe()
# Out:
#                                                      Data
# count                                                2627
# unique                                               2627
# top     Then several speakers  rose  and explained Ram...
# freq                                                    1

# %%
# Preprocessing the data
text = re.sub(r'\[[0-9]*\]',' ',str(data))
text = re.sub(r'\s+',' ',text)
text = text.lower()
text = re.sub(r'\d',' ',text)
text = re.sub(r'\s+',' ',text)

# %%
sentences = nltk.sent_tokenize(text)

sentences = [nltk.word_tokenize(sentence) for sentence in sentences]

# %%
sentences
# Out:
# [['data',
#   'the',
#   'bharatiya',
#   'vidya',
#   'bhavan',
#   'has',
#   'added',
#   'to',
#   '...',
#   'once',
#   'again',
#   ',',
#   'i',
#   'repeat',
#   'my',
#   'confession',
#   'that',
#   'in',
#   't',
#   '...',
#   'at',
#   'any',
#   'rate',
#   ',',
#   'they',
#   'embody',
#   'the',
#   'best',
#   'joy',
#   'i',
#   'have',
#   'e',
#   '...',
#   'in',
#   'presenting',
#   'this',
#   'english',
#   'version',
#   'to',
#   'a',
#   'wider',
#   '...',
#   'the',
#   'ramayana',
#   'is',
#   'not',
#   'history',
#   'or',
#   'biography',
#   '.'],
#  ['it',
#   '...',
#   'towards',
#   'things',
#   'spiritual',
#   'which',
#   'belongs',
#   'to',
#   '...',
#   'the',
#   'bharatiya',
#   'vidya',
#   'bhavan',
#   'has',
#   'achieved',
#   'great',
#   '...',
#   'oral',
#   'discourses',
#   'have',
#   'further',
#   'played',
#   'with',
#   'them',
#   '...',
#   'we',
#   'should',
#   'be',
#   'thankful',
#   'to',
#   'those',
#   'who',
#   'preserved',
#   'f',
#   '...',
#   'mythology',
#   'is',
#   'an',
#   'integral',
#   'part',
#   'of',
#   'religion',
#   '...',
#   'let',
#   'us',
#   'keep',
#   'ever',
#   'in',
#   'our',
#   'minds',
#   'the',
#   'fact',
#   'that',
#   'i',
#   '...',
#   'to',
#   'the',
#   'north',
#   'of',
#   'the',
#   'ganga',
#   'was',
#   'the',
#   'great',
#   'kingdo',
#   '...',
#   'king',
#   'dasaratha',
#   'ruled',
#   'the',
#   'kingdom',
#   'from',
#   'the',
#   '...',
#   'fought',
#   'on',
#   'the',
#   'side',
#   'of',
#   'the',
#   'devas',
#   ',',
#   'and',
#   'his',
#   'fam',
#   '...',
#   'it',
#   'contained',
#   'forts',
#   'with',
#   'moats',
#   'around',
#   'them',
#   'as',
#   '...',
#   'taxes',
#   'were',
#   'light',
#   'and',
#   'punishment',
#   'of',
#   'crime',
#   'wa',
#   '...',
#   'one',
#   'day',
#   'in',
#   'early',
#   'summer',
#   'he',
#   'thought',
#   'of',
#   'performi',
#   '...',
#   'it',
#   'meant',
#   'the',
#   'building',
#   'of',
#   'a',
#   'new',
#   'camp-',
#   'city',
#   ',',
#   'c',
#   '...',
#   'when',
#   'all',
#   'arrangements',
#   'were',
#   'complete',
#   'the',
#   'cere',
#   '...',
#   'as',
#   'enjoined',
#   'by',
#   'the',
#   'shastras',
#   '.'],
#  ['contemporaneously',
#   'with',
#   'the',
#   'yaga',
#   'in',
#   'ayodhya',
#   ',',
#   'th',
#   '...',
#   'refuge',
#   'and',
#   'it',
#   'is',
#   'for',
#   'you',
#   'to',
#   'devise',
#   'a',
#   'method',
#   '...',
#   'brahma',
#   'knew',
#   'that',
#   'he',
#   'had',
#   'granted',
#   'to',
#   'ravana',
#   'the',
#   '...',
#   'absolutely',
#   'surrendering',
#   'themselves',
#   'to',
#   'hari',
#   ',',
#   'th',
#   '...',
#   'calling',
#   'king',
#   'dasaratha',
#   'by',
#   'his',
#   'name',
#   ',',
#   'the',
#   'f',
#   '...',
#   'he',
#   'asked',
#   'kausalya',
#   'to',
#   'drink',
#   'a',
#   'half',
#   'of',
#   'the',
#   'pa',
#   '...',
#   '.'],
#  ['sage',
#   'viswamitra',
#   'in',
#   'course',
#   'of',
#   'time',
#   ',',
#   'dasaratha',
#   "'s",
#   'sons',
#   'were',
#   'born',
#   '...',
#   'of',
#   'kaikeyi',
#   '.'],
#  ['sumitra',
#   'gave',
#   'birth',
#   'to',
#   'twins',
#   ',',
#   'laksh',
#   '...',
#   'in',
#   'proportion',
#   'to',
#   'the',
#   'quantity',
#   'of',
#   'payasam',
#   'drun',
#   '...',
#   '...',
#   '...',
#   'in',
#   'love',
#   'that',
#   'is',
#   'not',
#   'opposed',
#   'to',
#   'dharma',
#   ',',
#   'we',
#   'fi',
#   '...',
#   'those',
#   'who',
#   'regard',
#   'the',
#   'ramayana',
#   'as',
#   'an',
#   'allegory',
#   '...',
#   'there',
#   'are',
#   'also',
#   'other',
#   'interpretations',
#   'and',
#   'appli',
#   '...',
#   'parvati',
#   "'s",
#   'function',
#   'in',
#   'relation',
#   'to',
#   'siva',
#   '...',
#   'many',
#   'meanings',
#   'can',
#   'be',
#   'read',
#   'in',
#   'the',
#   'ramayana',
#   'an',
#   '...',
#   'many',
#   'faults',
#   'in',
#   'what',
#   'i',
#   'have',
#   'written',
#   '.'],
#  ['but',
#   't',
#   '...',
#   'a',
#   'word',
#   'to',
#   'the',
#   'children',
#   'who',
#   'read',
#   'these',
#   'chapters',
#   '...',
#   'you',
#   'should',
#   'look',
#   'upon',
#   'rama',
#   ',',
#   'lakshmana',
#   'and',
#   'han',
#   '...',
#   'mothers',
#   'too',
#   ',',
#   'i',
#   'know',
#   ',',
#   'have',
#   'been',
#   'reading',
#   'this',
#   'st',
#   '...',
#   'the',
#   'story',
#   'of',
#   'sita',
#   'as',
#   'told',
#   'by',
#   'valmiki',
#   'and',
#   'k',
#   '...',
#   'in',
#   'the',
#   'rama',
#   'avatar',
#   ',',
#   'rama',
#   'did',
#   'not',
#   'know',
#   'that',
#   '...',
#   'knew',
#   'that',
#   'he',
#   'was',
#   'an',
#   'avatar',
#   'and',
#   'acted',
#   'according',
#   '...',
#   'led',
#   'the',
#   'warrior',
#   'to',
#   'destroy',
#   'the',
#   'wicked',
#   '.'],
#  ['in',
#   'ever',
#   '...',
#   'i',
#   'have',
#   'followed',
#   'the',
#   'story',
#   'of',
#   'the',
#   'prince',
#   'of',
#   '...',
#   'this',
#   'pathetic',
#   'episode',
#   'must',
#   'have',
#   'sprung',
#   'from',
#   'th',
#   '...',
#   'as',
#   'the',
#   'prince',
#   'returned',
#   'from',
#   'mithila',
#   'he',
#   'met',
#   'pa',
#   '...',
#   'on',
#   'this',
#   'theory',
#   ',',
#   'rama',
#   "'s",
#   'treatment',
#   'of',
#   'sita',
#   'aft',
#   '...',
#   'but',
#   ',',
#   'how',
#   'can',
#   'we',
#   'comment',
#   'on',
#   'a',
#   'work',
#   'composed',
#   'tho',
#   '...',
#   'sorrow',
#   'and',
#   'joy',
#   'are',
#   'both',
#   'alike',
#   'the',
#   'play',
#   'of',
#   'go',
#   '...',
#   'men',
#   'and',
#   'women',
#   ',',
#   'and',
#   'enacted',
#   'with',
#   'her',
#   'a',
#   'great',
#   'dr',
#   '...',
#   'rain',
#   'falling',
#   'from',
#   'the',
#   'heaven',
#   'flows',
#   'into',
#   'the',
#   '...',
#   'thus',
#   'in',
#   'every',
#   'land',
#   'the',
#   'poets',
#   'and',
#   'their',
#   'people',
#   '...',
#   'does',
#   'a',
#   'plant',
#   'spring',
#   'from',
#   'the',
#   'seed',
#   'or',
#   'does',
#   'se',
#   '...',
#   'one',
#   'other',
#   'point',
#   ',',
#   'in',
#   'describing',
#   'how',
#   'ravana',
#   'carr',
#   '...',
#   'it',
#   'is',
#   'no',
#   'sin',
#   'or',
#   'shame',
#   'to',
#   'an',
#   'innocent',
#   'woman',
#   'i',
#   '...',
#   'yet',
#   ',',
#   'mistakenly',
#   ',',
#   'we',
#   'in',
#   'this',
#   'country',
#   'look',
#   'o',
#   '...',
#   'deference',
#   'to',
#   'this',
#   'wrong',
#   'feeling',
#   'that',
#   'kamban',
#   '...',
#   'for',
#   'the',
#   'same',
#   'reason',
#   ',',
#   'tulasidas',
#   'relates',
#   'that',
#   'th',
#   '...',
#   'it',
#   'was',
#   'perhaps',
#   'presumptuous',
#   'on',
#   'my',
#   'part',
#   'to',
#   'hav',
#   '...',
#   'when',
#   'i',
#   'had',
#   'to',
#   'step',
#   'down',
#   'from',
#   'high',
#   'office',
#   'and',
#   '...',
#   '[',
#   'rows',
#   'x',
#   'columns',
#   ']']]

# %%
for i in range(len(sentences)):
    sentences[i] = [word for word in sentences[i] if word not in stopwords.words('english') ]

# %%
sentences
# Out:
# [['data',
#   'bharatiya',
#   'vidya',
#   'bhavan',
#   'added',
#   '...',
#   ',',
#   'repeat',
#   'confession',
#   '...',
#   'rate',
#   ',',
#   'embody',
#   'best',
#   'joy',
#   'e',
#   '...',
#   'presenting',
#   'english',
#   'version',
#   'wider',
#   '...',
#   'ramayana',
#   'history',
#   'biography',
#   '.'],
#  ['...',
#   'towards',
#   'things',
#   'spiritual',
#   'belongs',
#   '...',
#   'bharatiya',
#   'vidya',
#   'bhavan',
#   'achieved',
#   'great',
#   '...',
#   'oral',
#   'discourses',
#   'played',
#   '...',
#   'thankful',
#   'preserved',
#   'f',
#   '...',
#   'mythology',
#   'integral',
#   'part',
#   'religion',
#   '...',
#   'let',
#   'us',
#   'keep',
#   'ever',
#   'minds',
#   'fact',
#   '...',
#   'north',
#   'ganga',
#   'great',
#   'kingdo',
#   '...',
#   'king',
#   'dasaratha',
#   'ruled',
#   'kingdom',
#   '...',
#   'fought',
#   'side',
#   'devas',
#   ',',
#   'fam',
#   '...',
#   'contained',
#   'forts',
#   'moats',
#   'around',
#   '...',
#   'taxes',
#   'light',
#   'punishment',
#   'crime',
#   'wa',
#   '...',
#   'one',
#   'day',
#   'early',
#   'summer',
#   'thought',
#   'performi',
#   '...',
#   'meant',
#   'building',
#   'new',
#   'camp-',
#   'city',
#   ',',
#   'c',
#   '...',
#   'arrangements',
#   'complete',
#   'cere',
#   '...',
#   'enjoined',
#   'shastras',
#   '.'],
#  ['contemporaneously',
#   'yaga',
#   'ayodhya',
#   ',',
#   'th',
#   '...',
#   'refuge',
#   'devise',
#   'method',
#   '...',
#   'brahma',
#   'knew',
#   'granted',
#   'ravana',
#   '...',
#   'absolutely',
#   'surrendering',
#   'hari',
#   ',',
#   'th',
#   '...',
#   'calling',
#   'king',
#   'dasaratha',
#   'name',
#   ',',
#   'f',
#   '...',
#   'asked',
#   'kausalya',
#   'drink',
#   'half',
#   'pa',
#   '...',
#   '.'],
#  ['sage',
#   'viswamitra',
#   'course',
#   'time',
#   ',',
#   'dasaratha',
#   "'s",
#   'sons',
#   'born',
#   '...',
#   'kaikeyi',
#   '.'],
#  ['sumitra',
#   'gave',
#   'birth',
#   'twins',
#   ',',
#   'laksh',
#   '...',
#   'proportion',
#   'quantity',
#   'payasam',
#   'drun',
#   '...',
#   '...',
#   '...',
#   'love',
#   'opposed',
#   'dharma',
#   ',',
#   'fi',
#   '...',
#   'regard',
#   'ramayana',
#   'allegory',
#   '...',
#   'also',
#   'interpretations',
#   'appli',
#   '...',
#   'parvati',
#   "'s",
#   'function',
#   'relation',
#   'siva',
#   '...',
#   'many',
#   'meanings',
#   'read',
#   'ramayana',
#   '...',
#   'many',
#   'faults',
#   'written',
#   '.'],
#  ['...',
#   'word',
#   'children',
#   'read',
#   'chapters',
#   '...',
#   'look',
#   'upon',
#   'rama',
#   ',',
#   'lakshmana',
#   'han',
#   '...',
#   'mothers',
#   ',',
#   'know',
#   ',',
#   'reading',
#   'st',
#   '...',
#   'story',
#   'sita',
#   'told',
#   'valmiki',
#   'k',
#   '...',
#   'rama',
#   'avatar',
#   ',',
#   'rama',
#   'know',
#   '...',
#   'knew',
#   'avatar',
#   'acted',
#   'according',
#   '...',
#   'led',
#   'warrior',
#   'destroy',
#   'wicked',
#   '.'],
#  ['ever',
#   '...',
#   'followed',
#   'story',
#   'prince',
#   '...',
#   'pathetic',
#   'episode',
#   'must',
#   'sprung',
#   'th',
#   '...',
#   'prince',
#   'returned',
#   'mithila',
#   'met',
#   'pa',
#   '...',
#   'theory',
#   ',',
#   'rama',
#   "'s",
#   'treatment',
#   'sita',
#   'aft',
#   '...',
#   ',',
#   'comment',
#   'work',
#   'composed',
#   'tho',
#   '...',
#   'sorrow',
#   'joy',
#   'alike',
#   'play',
#   'go',
#   '...',
#   'men',
#   'women',
#   ',',
#   'enacted',
#   'great',
#   'dr',
#   '...',
#   'rain',
#   'falling',
#   'heaven',
#   'flows',
#   '...',
#   'thus',
#   'every',
#   'land',
#   'poets',
#   'people',
#   '...',
#   'plant',
#   'spring',
#   'seed',
#   'se',
#   '...',
#   'one',
#   'point',
#   ',',
#   'describing',
#   'ravana',
#   'carr',
#   '...',
#   'sin',
#   'shame',
#   'innocent',
#   'woman',
#   '...',
#   'yet',
#   ',',
#   'mistakenly',
#   ',',
#   'country',
#   'look',
#   '...',
#   'deference',
#   'wrong',
#   'feeling',
#   'kamban',
#   '...',
#   'reason',
#   ',',
#   'tulasidas',
#   'relates',
#   'th',
#   '...',
#   'perhaps',
#   'presumptuous',
#   'part',
#   'hav',
#   '...',
#   'step',
#   'high',
#   'office',
#   '...',
#   '[',
#   'rows',
#   'x',
#   'columns',
#   ']']]

# %%
# Training the Word2Vec model
model = Word2Vec(sentences, min_count=1)

# %%
words = model.wv.vocab

# %%
# Finding Word Vectors
vector = model.wv['ramayana']

# %%
vector
# Out:
# array([ 3.4335072e-03,  3.4446300e-03, -3.0396867e-03,  2.0637049e-03,
#        -3.9674547e-03,  3.0628834e-03,  3.4256233e-03, -1.7799720e-03,
#         3.4003374e-03, -3.0596221e-03,  2.2765461e-03, -3.4447087e-03,
#        -1.6557053e-04, -1.1291319e-03, -4.8535512e-04,  3.2397653e-03,
#         3.1644588e-03,  2.6946410e-03, -3.4088863e-03, -8.2184248e-05,
#        -4.6595153e-03,  4.6058828e-03, -3.8468509e-03, -1.1482340e-03,
#         4.2287447e-03,  1.4413825e-04,  3.8052914e-03, -3.8143811e-03,
#         4.0495070e-03,  2.6356585e-03,  3.2509807e-03, -2.7522363e-03,
#         1.4113910e-03,  3.2847445e-03,  4.8761978e-03, -2.0121054e-03,
#         1.2245935e-03,  3.5444174e-03,  5.0796912e-04, -1.4974469e-03,
#        -3.6811172e-03, -2.8672640e-03, -3.6145831e-03, -2.7232927e-03,
#        -1.4384147e-03,  4.9651861e-03, -4.7268495e-03,  3.6210369e-03,
#         7.0860982e-04, -4.4561531e-03, -7.5397978e-04, -1.2426316e-04,
#         1.5763812e-03,  2.0690830e-03, -2.8961743e-04, -4.6392726e-03,
#        -3.2378794e-03, -3.4357377e-04, -4.7701783e-03,  7.4367726e-04,
#         3.6921210e-03, -3.2666484e-03, -3.6979781e-03,  9.6885889e-04,
#         1.2809607e-04,  4.1342764e-03, -3.8636624e-04,  1.7230522e-03,
#         7.5446547e-04,  3.3767042e-03,  4.1366369e-03, -2.2877617e-04,
#         4.6102316e-04, -4.3634828e-03,  1.5088131e-03, -1.4760672e-03,
#         2.7924133e-03,  2.9903024e-03, -6.2746677e-04, -3.1264583e-03,
#         2.6103337e-03,  5.0400705e-03,  3.9499914e-03,  2.6442783e-03,
#        -4.0004747e-03,  7.9797197e-04,  2.9873485e-03,  2.1722978e-03,
#         3.4188170e-03, -4.0979115e-03,  1.2868223e-03, -2.0422039e-03,
#         3.9135250e-03, -1.4154759e-03, -6.8118254e-04, -4.4390783e-03,
#        -4.1842521e-03,  2.3964699e-03, -1.9554030e-03, -9.0066297e-04],
#       dtype=float32)

# %%
# Most similar words
similar = model.wv.most_similar('ravana')

# %%
similar
# Out:
# [('fam', 0.2492617815732956),
#  ('played', 0.2091265320777893),
#  ('shame', 0.18487106263637543),
#  ('data', 0.17571447789669037),
#  ('dasaratha', 0.17149829864501953),
#  ('bhavan', 0.16956298053264618),
#  ('dharma', 0.1675669252872467),
#  ('meant', 0.16716152429580688),
#  ('valmiki', 0.1656382977962494),
#  ('tulasidas', 0.16448378562927246)]
